# %% [markdown]
# #Preprocesamiento y calidad de datos.

# %% [markdown]
# ##Base de datos de partida y carga de datos

# %% [markdown]
# Los datos se pueden descargar a través de la página web www.opendatalapalma.es, el portal de acceso a los datos públicos del Cabildo de La Palma.

# %%
# Importamos librerías
import shutil
import pandas as pd
import numpy as np
import seaborn as sns
import io
from google.colab import files
import itertools
from numpy import corrcoef, transpose, arange
from pylab import pcolor, show, colorbar, xticks, yticks
from sklearn.preprocessing import MinMaxScaler

import matplotlib.pyplot as plt
import matplotlib.mlab as mlab
import matplotlib
plt.style.use('ggplot')
from matplotlib.pyplot import figure

# %matplotlib inline
matplotlib.rcParams['figure.figsize'] = (12,8)

pd.options.mode.chained_assignment = None

from pylab import pcolor, show, colorbar, xticks, yticks

# %% [markdown]
# Leemos el fichero de fuente de datos, que previamente hemos importado.

# %%
df = pd.read_csv("Movimientos_sismicos.csv")
print(df)
# Out:
#              X        Y  OBJECTID_1  OBJECTID  Id  Date_  Time_  \
# 0     -17.8807  28.5661       70306       NaN NaN    NaN    NaN
# 1     -17.8508  28.5584       70307       NaN NaN    NaN    NaN
# 2     -17.8735  28.5719       70308       NaN NaN    NaN    NaN
# 3     -17.8802  28.5656       70309       NaN NaN    NaN    NaN
# 4     -17.8549  28.5499       70310       NaN NaN    NaN    NaN
# ...        ...      ...         ...       ...  ..    ...    ...
# 15557 -17.8804  28.6190       85865       NaN NaN    NaN    NaN
# 15558 -17.8451  28.5525       85866       NaN NaN    NaN    NaN
# 15559 -17.9003  28.6054       85867       NaN NaN    NaN    NaN
# 15560 -17.8845  28.6263       85868       NaN NaN    NaN    NaN
# 15561 -17.8634  28.5679       85869       NaN NaN    NaN    NaN
#
#                         DateTime_  ErrTime   RMS  ...    Qual  Author  \
# 0      2017/10/07 10:27:29.820+00     2.18  0.19  ...  m i ke     IGN
# 1      2017/10/07 13:03:25.460+00     2.19  0.20  ...  m i ke     IGN
# 2      2017/10/07 20:09:58.790+00     2.33  0.16  ...  m i ke     IGN
# 3          2017/10/07 23:06:00+00     2.44  0.11  ...  m i ke     IGN
# 4      2017/10/08 01:23:02.150+00     1.93  0.17  ...  m i ke     IGN
# ...                           ...      ...   ...  ...     ...     ...
# 15557  2022/02/10 02:48:10.490+00     0.68  0.43  ...  m i ke     IGN
# 15558  2022/02/10 04:26:19.090+00     1.29  0.22  ...  m i ke     IGN
# 15559  2022/02/10 04:29:03.150+00     0.80  0.37  ...  m i ke     IGN
# 15560  2022/02/10 05:12:46.630+00     0.87  0.45  ...  m i ke     IGN
# 15561      2022/02/10 06:05:20+00     2.02  0.21  ...  m i ke     IGN
#
#             OrigID  Magnitud  IntensMax  Localizaci  TipoMagnit    XUTM  \
# 0      es2017mbfgp       1.6        NaN         NaN        mbLg  218191
# 1      es2017mbgkc       2.7        NaN         NaN        mbLg  221097
# 2      es2017mbjoj       1.7        NaN         NaN        mbLg  218912
# 3      es2017mblee       1.7        NaN         NaN        mbLg  218239
# 4      es2017mbmfb       2.6        NaN         NaN        mbLg  220674
# ...            ...       ...        ...         ...         ...     ...
# 15557  es2022cvicb       0.9        NaN         NaN        mbLg  218362
# 15558  es2022cvlig       1.4        NaN         NaN        mbLg  221640
# 15559  es2022cvlkp       0.9        NaN         NaN        mbLg  216379
# 15560  es2022cvmwc       0.8        NaN         NaN        mbLg  217980
# 15561  es2022cvopf       1.2        NaN         NaN        mbLg  219889
#
#           YUTM  GlobalID
# 0      3163304       NaN
# 1      3162380       NaN
# 2      3163930       NaN
# 3      3163248       NaN
# 4      3161448       NaN
# ...        ...       ...
# 15557  3169168       NaN
# 15558  3161713       NaN
# 15559  3167707       NaN
# 15560  3169987       NaN
# 15561  3163463       NaN
#
# [15562 rows x 32 columns]

# %% [markdown]
# Comprobamos los tipos y la cantidad de instacias que tenemos

# %%
#Forma y tipos de datos de los datos
print(df.shape)
print(df.dtypes)
# Out:
# (15562, 32)
# X             float64
# Y             float64
# OBJECTID_1      int64
# OBJECTID      float64
# Id            float64
# Date_         float64
# Time_         float64
# DateTime_      object
# ErrTime       float64
# RMS           float64
# Latitude      float64
# Longitude     float64
# Smaj          float64
# Smin          float64
# Az              int64
# Depth         float64
# ErrDepth      float64
# Ndef            int64
# Nsta            int64
# Gap             int64
# mdist         float64
# Mdist_        float64
# Qual           object
# Author         object
# OrigID         object
# Magnitud      float64
# IntensMax     float64
# Localizaci    float64
# TipoMagnit     object
# XUTM            int64
# YUTM            int64
# GlobalID      float64
# dtype: object

# %% [markdown]
# Luego, en el datasets en estudio constan 15562 ejemplos diferentes con 32 variables.

# %% [markdown]
# Subconjunto de variables númericas:

# %%
#Se seleccionan columnas numéricas
df_numeric = df.select_dtypes(include=[np.number])      #Se crea un data frame nuevo que seleccione las columnas de tipo numérico.
numeric_cols = df_numeric.columns.values
print(numeric_cols)
# Out:
# ['X' 'Y' 'OBJECTID_1' 'OBJECTID' 'Id' 'Date_' 'Time_' 'ErrTime' 'RMS'
#  'Latitude' 'Longitude' 'Smaj' 'Smin' 'Az' 'Depth' 'ErrDepth' 'Ndef'
#  'Nsta' 'Gap' 'mdist' 'Mdist_' 'Magnitud' 'IntensMax' 'Localizaci' 'XUTM'
#  'YUTM' 'GlobalID']

# %%
print(df_numeric.shape)
# Out:
# (15562, 27)

# %% [markdown]
# Hacemos lo mismo con las variables que no son númericas.

# %%
#Se seleccionan columnas no numéricas
df_non_numeric = df.select_dtypes(exclude=[np.number])      #Se crea un data frame nuevo que seleccione las columnas de tipo no numérico.
non_numeric_cols = df_non_numeric.columns.values
print(non_numeric_cols)
# Out:
# ['DateTime_' 'Qual' 'Author' 'OrigID' 'TipoMagnit']

# %%
print(df_non_numeric.shape)
# Out:
# (15562, 5)

# %% [markdown]
# De estos resultados, aprendemos que el conjunto de datos tiene 15.562 filas y 32 columnas. También identificamos si las características son variables numéricas o categóricas. En concreto, se cuenta con 27 variables de tipo numérico y 5 variables categóricas. Es posible que no todas estas variables sean información útil. Este hecho da lugar al siguiente punto.

# %% [markdown]
# # Missing values

# %% [markdown]
# ## Missing Data Heatmap
# Cuando hay un número menor de características, es útil visualizar los datos que faltan a través del mapa de calor.
#
#  Se puede utilizar un único mapa de calor para las **32** características, ya que se aprecia comodamente los "missing values".

# %%
#Primer gráfico con las 32 categorías.
cols = df.columns[:33]                    #32 columnas.
colours = ['#FF00FF', '#40E0D0']          #Se especifica el color turquesa para datos faltantes y fucsia para no faltantes.
sns.heatmap(df[cols].isnull(), cmap=sns.color_palette(colours))
# Out:
# <Axes: >

# %% [markdown]
# El gráfico que figura  muestra los patrones de datos que faltan de las 32 características. El eje horizontal muestra el nombre del atributo de entrada; el eje vertical muestra el número de observaciones/filas; el color turquesa representa los datos que faltan, mientras que el color fucsia, en caso contrario.
# Por ejemplo, vemos que la característica *OBJECTID_1*, *Id*, *Date_*, *Time_*, *IntensMax*, *Localizacion* y *GlobalID* tiene valores perdidos en todas las filas. Por otra parte, el resto de las características no tienen valores perdidos.

# %% [markdown]
# ## Missing Data Percentage List
# También podemos hacer una lista de los porcentajes de datos que faltan para cada característica. Es útil cuando se dispone muchas características en el conjunto de datos.

# %%
#Si se trata de un conjunto de datos más grande y la visualización lleva demasiado tiempo, conviene hacerlo.
#Porcentaje de valores perdidos.
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# X - 0%
# Y - 0%
# OBJECTID_1 - 0%
# OBJECTID - 100%
# Id - 100%
# Date_ - 100%
# Time_ - 100%
# DateTime_ - 0%
# ErrTime - 0%
# RMS - 0%
# Latitude - 0%
# Longitude - 0%
# Smaj - 0%
# Smin - 0%
# Az - 0%
# Depth - 0%
# ErrDepth - 0%
# Ndef - 0%
# Nsta - 0%
# Gap - 0%
# mdist - 0%
# Mdist_ - 0%
# Qual - 0%
# Author - 0%
# OrigID - 0%
# Magnitud - 0%
# IntensMax - 100%
# Localizaci - 100%
# TipoMagnit - 0%
# XUTM - 0%
# YUTM - 0%
# GlobalID - 100%

# %% [markdown]
# Esto produce una lista que muestra el porcentaje de valores faltantes para cada una de las características. En concreto, se observa que tenemos características totalmente vacías:
# 1. OBJECTID - 100%
# 2. Id - 100%
# 3. Date_ - 100%
# 4. Time_ - 100%
# 5. IntensMax - 100%
# 6. Localizaci - 100%
# 7. GlobalID - 100%

# %% [markdown]
# Cuando llegue el momento serán borradas porque estas características no contienen ni un solo dato y, por ende, no aportan ninguna información.
#
# No existen otras variables con un alto porcentaje de valores perdidos o con un porcentaje menos significativo donde se tenga que decidir que hacer con ellas.
#
# Esta claro que la lista de porcentajes generada es un resumen útil que puede complementar la visualización del mapa de calor.

# %% [markdown]
# ##Dejar o no dejar la característica
# Eliminamos la característica cuando estamos seguros de que esta no proporciona información útil.
#
# Por ejemplo, de la lista de porcentajes de datos faltantes, se había comentado una serie de características totalmente vacías.
#
# Por otra parte, hay que estar seguro de que una característica no proporciona información útil para que sea borrada. Luego, se decide eliminar únicamente aquellas características cuyo porcentaje de valores faltantes es el 100%. Estas son:
# 1. OBJECTID - 100%
# 2. Id - 100%
# 3. Date_ - 100%
# 4. Time_ - 100%
# 5. IntensMax - 100%
# 6. Localizaci - 100%
# 7. GlobalID - 100%

# %%
df = df_numeric
df.drop(["OBJECTID",'Id','Date_','Time_','IntensMax', 'Localizaci', 'GlobalID'], axis = 1, inplace = True)
df.head()
# Out:
#          X        Y  OBJECTID_1  ErrTime   RMS  Latitude  Longitude  Smaj  \
# 0 -17.8807  28.5661       70306     2.18  0.19   28.5661   -17.8807  16.6
# 1 -17.8508  28.5584       70307     2.19  0.20   28.5584   -17.8508  46.7
# 2 -17.8735  28.5719       70308     2.33  0.16   28.5719   -17.8735  18.9
# 3 -17.8802  28.5656       70309     2.44  0.11   28.5656   -17.8802  18.3
# 4 -17.8549  28.5499       70310     1.93  0.17   28.5499   -17.8549  19.7
#
#    Smin  Az  Depth  ErrDepth  Ndef  Nsta  Gap  mdist  Mdist_  Magnitud  \
# 0  10.4  81   21.6      12.7     9     5  189   0.02    0.20       1.6
# 1  13.6  67   28.2      13.0     8     4  149   0.03    0.13       2.7
# 2  10.1  87   24.2      14.0     8     5  181   0.01    0.19       1.7
# 3  12.1  87   24.4      13.7     8     5  189   0.02    0.20       1.7
# 4  10.8  90   26.3      11.5    10     5  168   0.03    0.20       2.6
#
#      XUTM     YUTM
# 0  218191  3163304
# 1  221097  3162380
# 2  218912  3163930
# 3  218239  3163248
# 4  220674  3161448

# %% [markdown]
# La variable OBJECTID_1 la detecta como numérica cuando realmente no lo es, es un identificador único para el evento del terremoto.

# %%
df.drop(["OBJECTID_1"], axis = 1, inplace = True)
df.head()
# Out:
#          X        Y  ErrTime   RMS  Latitude  Longitude  Smaj  Smin  Az  \
# 0 -17.8807  28.5661     2.18  0.19   28.5661   -17.8807  16.6  10.4  81
# 1 -17.8508  28.5584     2.19  0.20   28.5584   -17.8508  46.7  13.6  67
# 2 -17.8735  28.5719     2.33  0.16   28.5719   -17.8735  18.9  10.1  87
# 3 -17.8802  28.5656     2.44  0.11   28.5656   -17.8802  18.3  12.1  87
# 4 -17.8549  28.5499     1.93  0.17   28.5499   -17.8549  19.7  10.8  90
#
#    Depth  ErrDepth  Ndef  Nsta  Gap  mdist  Mdist_  Magnitud    XUTM     YUTM
# 0   21.6      12.7     9     5  189   0.02    0.20       1.6  218191  3163304
# 1   28.2      13.0     8     4  149   0.03    0.13       2.7  221097  3162380
# 2   24.2      14.0     8     5  181   0.01    0.19       1.7  218912  3163930
# 3   24.4      13.7     8     5  189   0.02    0.20       1.7  218239  3163248
# 4   26.3      11.5    10     5  168   0.03    0.20       2.6  220674  3161448

# %%
#Comprobación
for col in df.columns:
    pct_missing = np.mean(df[col].isnull())
    print('{} - {}%'.format(col, round(pct_missing*100)))
# Out:
# X - 0%
# Y - 0%
# ErrTime - 0%
# RMS - 0%
# Latitude - 0%
# Longitude - 0%
# Smaj - 0%
# Smin - 0%
# Az - 0%
# Depth - 0%
# ErrDepth - 0%
# Ndef - 0%
# Nsta - 0%
# Gap - 0%
# mdist - 0%
# Mdist_ - 0%
# Magnitud - 0%
# XUTM - 0%
# YUTM - 0%

# %% [markdown]
# Se obtiene una lista donde el porcentaje de valores perdidos para cada variable es nulo.
# Nuestro Datasets está limpio. de datos faltantes.

# %% [markdown]
# ##Outliers

# %% [markdown]
# Sí debes normalizar si:
#
# Las variables tienen escalas muy diferentes (ej. magnitud de sismos vs. profundidad en km).

# %%
scaler = MinMaxScaler()
data_norm = pd.DataFrame(scaler.fit_transform(df), columns=df.columns)

plt.figure(figsize=(12, 8))
sns.boxplot(data=data_norm)
plt.title("Box Plot")
plt.xticks(rotation=45, ha='right')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Selección de características

# %% [markdown]
# Para empezar cargamos los datos en un DataFrame de la librería Pandas y mostramos nuevamente los datos:

# %%
#Si se trata de un conjunto de datos más grande y la visualización lleva demasiado tiempo, conviene hacer una lista de porcentajes de valores perdidos.
import pandas as pd
import io
df.head(5)
# Out:
#          X        Y  ErrTime   RMS  Latitude  Longitude  Smaj  Smin  Az  \
# 0 -17.8807  28.5661     2.18  0.19   28.5661   -17.8807  16.6  10.4  81
# 1 -17.8508  28.5584     2.19  0.20   28.5584   -17.8508  46.7  13.6  67
# 2 -17.8735  28.5719     2.33  0.16   28.5719   -17.8735  18.9  10.1  87
# 3 -17.8802  28.5656     2.44  0.11   28.5656   -17.8802  18.3  12.1  87
# 4 -17.8549  28.5499     1.93  0.17   28.5499   -17.8549  19.7  10.8  90
#
#    Depth  ErrDepth  Ndef  Nsta  Gap  mdist  Mdist_  Magnitud    XUTM     YUTM
# 0   21.6      12.7     9     5  189   0.02    0.20       1.6  218191  3163304
# 1   28.2      13.0     8     4  149   0.03    0.13       2.7  221097  3162380
# 2   24.2      14.0     8     5  181   0.01    0.19       1.7  218912  3163930
# 3   24.4      13.7     8     5  189   0.02    0.20       1.7  218239  3163248
# 4   26.3      11.5    10     5  168   0.03    0.20       2.6  220674  3161448

# %% [markdown]
# # Correlación entre variables

# %% [markdown]
# Se calcula, mediante el test de correlación de Pearson, los coeficientes de correlaciones que se corresponde con cada uno de los posibles pares de las variables del conjunto de datos en estudio.

# %%
df_feat = df
df_feat = df_feat.astype('float')
corr_df = df_feat.corr(method='pearson')

print("El DataFrame de correlaciones es:")
print(corr_df, "\n")
# Out:
# El DataFrame de correlaciones es:
#                   X         Y   ErrTime       RMS  Latitude  Longitude  \
# X          1.000000  0.145250 -0.149929  0.161982  0.145250   1.000000
# Y          0.145250  1.000000 -0.179837 -0.082394  1.000000   0.145250
# ErrTime   -0.149929 -0.179837  1.000000 -0.281757 -0.179837  -0.149929
# RMS        0.161982 -0.082394 -0.281757  1.000000 -0.082394   0.161982
# Latitude   0.145250  1.000000 -0.179837 -0.082394  1.000000   0.145250
# Longitude  1.000000  0.145250 -0.149929  0.161982  0.145250   1.000000
# Smaj      -0.042730 -0.293235  0.749360 -0.163479 -0.293235  -0.042730
# Smin      -0.108811 -0.283588  0.869371 -0.209161 -0.283588  -0.108811
# Az         0.134751  0.676339 -0.352597  0.079522  0.676339   0.134751
# Depth      0.021400 -0.467162  0.580249 -0.051372 -0.467162   0.021400
# ErrDepth   0.056517 -0.074598  0.789362 -0.109115 -0.074598   0.056517
# Ndef       0.113241 -0.418152 -0.511128  0.315976 -0.418152   0.113241
# Nsta       0.117685 -0.392264 -0.447668  0.419744 -0.392264   0.117685
# Gap       -0.149383  0.005662  0.662708 -0.104339  0.005662  -0.149383
# mdist      0.397034  0.076234  0.071121  0.209374  0.076234   0.397034
# Mdist_     0.109222 -0.237587 -0.279091  0.400242 -0.237587   0.109222
# Magnitud   0.045353 -0.590548 -0.265741  0.256920 -0.590548   0.045353
# XUTM       0.090885 -0.005827 -0.011746  0.128970 -0.005827   0.090885
# YUTM       0.133670  0.999931 -0.178271 -0.084523  0.999931   0.133670
#
#                Smaj      Smin        Az     Depth  ErrDepth      Ndef  \
# X         -0.042730 -0.108811  0.134751  0.021400  0.056517  0.113241
# Y         -0.293235 -0.283588  0.676339 -0.467162 -0.074598 -0.418152
# ErrTime    0.749360  0.869371 -0.352597  0.580249  0.789362 -0.511128
# RMS       -0.163479 -0.209161  0.079522 -0.051372 -0.109115  0.315976
# Latitude  -0.293235 -0.283588  0.676339 -0.467162 -0.074598 -0.418152
# Longitude -0.042730 -0.108811  0.134751  0.021400  0.056517  0.113241
# Smaj       1.000000  0.849668 -0.390802  0.693909  0.686648 -0.346003
# Smin       0.849668  1.000000 -0.381506  0.734528  0.724998 -0.404294
# Az        -0.390802 -0.381506  1.000000 -0.471126 -0.201956 -0.225289
# Depth      0.693909  0.734528 -0.471126  1.000000  0.502214  0.066127
# ErrDepth   0.686648  0.724998 -0.201956  0.502214  1.000000 -0.426497
# Ndef      -0.346003 -0.404294 -0.225289  0.066127 -0.426497  1.000000
# Nsta      -0.271903 -0.327916 -0.142370  0.113515 -0.309058  0.918426
# Gap        0.553586  0.633397 -0.214403  0.254239  0.569138 -0.502973
# mdist      0.128085  0.097157  0.033810 -0.014195  0.378621 -0.059649
# Mdist_    -0.097882 -0.142350 -0.064002  0.117150 -0.089125  0.510230
# Magnitud  -0.048232 -0.099229 -0.443147  0.310870 -0.211198  0.773304
# XUTM       0.023646  0.018798  0.034991 -0.003822  0.095196  0.010400
# YUTM      -0.293184 -0.282736  0.675715 -0.468142 -0.075340 -0.420188
#
#                Nsta       Gap     mdist    Mdist_  Magnitud      XUTM  \
# X          0.117685 -0.149383  0.397034  0.109222  0.045353  0.090885
# Y         -0.392264  0.005662  0.076234 -0.237587 -0.590548 -0.005827
# ErrTime   -0.447668  0.662708  0.071121 -0.279091 -0.265741 -0.011746
# RMS        0.419744 -0.104339  0.209374  0.400242  0.256920  0.128970
# Latitude  -0.392264  0.005662  0.076234 -0.237587 -0.590548 -0.005827
# Longitude  0.117685 -0.149383  0.397034  0.109222  0.045353  0.090885
# Smaj      -0.271903  0.553586  0.128085 -0.097882 -0.048232  0.023646
# Smin      -0.327916  0.633397  0.097157 -0.142350 -0.099229  0.018798
# Az        -0.142370 -0.214403  0.033810 -0.064002 -0.443147  0.034991
# Depth      0.113515  0.254239 -0.014195  0.117150  0.310870 -0.003822
# ErrDepth  -0.309058  0.569138  0.378621 -0.089125 -0.211198  0.095196
# Ndef       0.918426 -0.502973 -0.059649  0.510230  0.773304  0.010400
# Nsta       1.000000 -0.431357 -0.019982  0.725460  0.745178  0.027424
# Gap       -0.431357  1.000000  0.262638 -0.182965 -0.361787  0.019406
# mdist     -0.019982  0.262638  1.000000  0.118597 -0.080076  0.305242
# Mdist_     0.725460 -0.182965  0.118597  1.000000  0.492825  0.086616
# Magnitud   0.745178 -0.361787 -0.080076  0.492825  1.000000  0.034318
# XUTM       0.027424  0.019406  0.305242  0.086616  0.034318  1.000000
# YUTM      -0.394318  0.007549  0.071691 -0.239283 -0.592091 -0.007595
#
#                YUTM
# X          0.133670
# Y          0.999931
# ErrTime   -0.178271
# RMS       -0.084523
# Latitude   0.999931
# Longitude  0.133670
# Smaj      -0.293184
# Smin      -0.282736
# Az         0.675715
# Depth     -0.468142
# ErrDepth  -0.075340
# Ndef      -0.420188
# Nsta      -0.394318
# Gap        0.007549
# mdist      0.071691
# Mdist_    -0.239283
# Magnitud  -0.592091
# XUTM      -0.007595
# YUTM       1.000000

# %% [markdown]
# La interpretación de estos valores es sencilla, basta con saber que aquellos valores cercanos a cero representan un menor grado de asociación entre un par de variables y los cercanos a 1 y -1 una mayor correlación entre el par de variables. Sin embargo, buscar aquellas características que están más, o menos, correladas en función de estos valores podría resultar algo tedioso, tal y como se han presentado. Así que podríamos apoyarnos en algún gráfico que muestre, de forma más clara, las correlaciones anteriores. Por ejemplo, los dos siguientes:

# %%
R = df_feat.corr()

sns.set(style="white")
mask = np.zeros_like(corr_df, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(200, 10, as_cmap=True)

sns.heatmap(corr_df,mask=mask, cmap=cmap,square = True, linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)
# Out:
# <Axes: >

# %%
corr_df.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_f2f06_row0_col0, #T_f2f06_row0_col5, #T_f2f06_row1_col1, #T_f2f06_row1_col4, #T_f2f06_row1_col18, #T_f2f06_row2_col2, #T_f2f06_row3_col3, #T_f2f06_row4_col1, #T_f2f06_row4_col4, #T_f2f06_row4_col18, #T_f2f06_row5_col0, #T_f2f06_row5_col5, #T_f2f06_row6_col6, #T_f2f06_row7_col7, #T_f2f06_row8_col8, #T_f2f06_row9_col9, #T_f2f06_row10_col10, #T_f2f06_row11_col11, #T_f2f06_row12_col12, #T_f2f06_row13_col13, #T_f2f06_row14_col14, #T_f2f06_row15_col15, #T_f2f06_row16_col16, #T_f2f06_row17_col17, #T_f2f06_row18_col1, #T_f2f06_row18_col4, #T_f2f06_row18_col18 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_f2f06_row0_col1, #T_f2f06_row0_col4, #T_f2f06_row5_col1, #T_f2f06_row5_col4 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_f2f06_row0_col2, #T_f2f06_row5_col2, #T_f2f06_row10_col16 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_f2f06_row0_col3, #T_f2f06_row5_col3, #T_f2f06_row17_col8, #T_f2f06_row17_col11, #T_f2f06_row17_col13 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_f2f06_row0_col6, #T_f2f06_row5_col6 {
#   background-color: #8db0fe;
#   color: #000000;
# }
# #T_f2f06_row0_col7, #T_f2f06_row5_col7, #T_f2f06_row8_col12, #T_f2f06_row15_col6, #T_f2f06_row17_col0, #T_f2f06_row17_col5 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_f2f06_row0_col8, #T_f2f06_row0_col11, #T_f2f06_row5_col8, #T_f2f06_row5_col11 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_f2f06_row0_col9, #T_f2f06_row5_col9 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_f2f06_row0_col10, #T_f2f06_row1_col13, #T_f2f06_row4_col13, #T_f2f06_row5_col10, #T_f2f06_row18_col13 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_f2f06_row0_col12, #T_f2f06_row5_col12, #T_f2f06_row9_col12 {
#   background-color: #bcd2f7;
#   color: #000000;
# }
# #T_f2f06_row0_col13, #T_f2f06_row5_col13, #T_f2f06_row15_col10 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_f2f06_row0_col14, #T_f2f06_row5_col14 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_f2f06_row0_col15, #T_f2f06_row5_col15, #T_f2f06_row17_col7 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_f2f06_row0_col16, #T_f2f06_row5_col16, #T_f2f06_row15_col9 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_f2f06_row0_col17, #T_f2f06_row5_col17 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_f2f06_row0_col18, #T_f2f06_row5_col18 {
#   background-color: #d1dae9;
#   color: #000000;
# }
# #T_f2f06_row1_col0, #T_f2f06_row1_col5, #T_f2f06_row4_col0, #T_f2f06_row4_col5 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_f2f06_row1_col2, #T_f2f06_row3_col10, #T_f2f06_row4_col2, #T_f2f06_row15_col1, #T_f2f06_row15_col4, #T_f2f06_row15_col18, #T_f2f06_row18_col2 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_f2f06_row1_col3, #T_f2f06_row4_col3, #T_f2f06_row15_col2, #T_f2f06_row18_col3 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_f2f06_row1_col6, #T_f2f06_row4_col6, #T_f2f06_row18_col6 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_f2f06_row1_col7, #T_f2f06_row4_col7, #T_f2f06_row18_col7 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_f2f06_row1_col8, #T_f2f06_row4_col8, #T_f2f06_row6_col10, #T_f2f06_row9_col6, #T_f2f06_row18_col8 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_f2f06_row1_col9, #T_f2f06_row1_col16, #T_f2f06_row2_col0, #T_f2f06_row2_col3, #T_f2f06_row2_col5, #T_f2f06_row2_col11, #T_f2f06_row2_col12, #T_f2f06_row2_col15, #T_f2f06_row2_col17, #T_f2f06_row4_col9, #T_f2f06_row4_col16, #T_f2f06_row8_col6, #T_f2f06_row8_col9, #T_f2f06_row9_col8, #T_f2f06_row11_col2, #T_f2f06_row11_col7, #T_f2f06_row11_col10, #T_f2f06_row11_col13, #T_f2f06_row13_col0, #T_f2f06_row13_col5, #T_f2f06_row16_col1, #T_f2f06_row16_col4, #T_f2f06_row16_col14, #T_f2f06_row16_col18, #T_f2f06_row18_col9, #T_f2f06_row18_col16 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_f2f06_row1_col10, #T_f2f06_row4_col10, #T_f2f06_row8_col0, #T_f2f06_row8_col5, #T_f2f06_row16_col6, #T_f2f06_row18_col0, #T_f2f06_row18_col5, #T_f2f06_row18_col10 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_f2f06_row1_col11, #T_f2f06_row4_col11, #T_f2f06_row7_col8, #T_f2f06_row9_col14, #T_f2f06_row18_col11 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_f2f06_row1_col12, #T_f2f06_row4_col12, #T_f2f06_row7_col0, #T_f2f06_row7_col5, #T_f2f06_row12_col17, #T_f2f06_row18_col12 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_f2f06_row1_col14, #T_f2f06_row4_col14, #T_f2f06_row13_col16 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_f2f06_row1_col15, #T_f2f06_row4_col15, #T_f2f06_row6_col17, #T_f2f06_row11_col6 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_f2f06_row1_col17, #T_f2f06_row4_col17, #T_f2f06_row13_col11, #T_f2f06_row18_col17 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_f2f06_row2_col1, #T_f2f06_row2_col4, #T_f2f06_row2_col18 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_f2f06_row2_col6, #T_f2f06_row7_col9 {
#   background-color: #ea7b60;
#   color: #f1f1f1;
# }
# #T_f2f06_row2_col7 {
#   background-color: #d44e41;
#   color: #f1f1f1;
# }
# #T_f2f06_row2_col8 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_f2f06_row2_col9, #T_f2f06_row10_col13 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_f2f06_row2_col10 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_f2f06_row2_col13, #T_f2f06_row10_col6, #T_f2f06_row13_col2 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_f2f06_row2_col14, #T_f2f06_row3_col7, #T_f2f06_row3_col17, #T_f2f06_row13_col3, #T_f2f06_row18_col14 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_f2f06_row2_col16 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_f2f06_row3_col0, #T_f2f06_row3_col5 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_f2f06_row3_col1, #T_f2f06_row3_col4, #T_f2f06_row3_col18, #T_f2f06_row13_col14, #T_f2f06_row17_col9 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_f2f06_row3_col2, #T_f2f06_row9_col0, #T_f2f06_row9_col5, #T_f2f06_row10_col15, #T_f2f06_row16_col10 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_f2f06_row3_col6, #T_f2f06_row16_col2 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_f2f06_row3_col8, #T_f2f06_row13_col1, #T_f2f06_row13_col4, #T_f2f06_row14_col6 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_f2f06_row3_col9, #T_f2f06_row17_col15 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_f2f06_row3_col11, #T_f2f06_row12_col3 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_f2f06_row3_col12 {
#   background-color: #f2cbb7;
#   color: #000000;
# }
# #T_f2f06_row3_col13 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_f2f06_row3_col14 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_f2f06_row3_col15 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_f2f06_row3_col16, #T_f2f06_row15_col3, #T_f2f06_row16_col9 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_f2f06_row6_col0, #T_f2f06_row6_col3, #T_f2f06_row6_col5, #T_f2f06_row8_col16 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_f2f06_row6_col1, #T_f2f06_row6_col4, #T_f2f06_row15_col7, #T_f2f06_row15_col14 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_f2f06_row6_col2 {
#   background-color: #e7745b;
#   color: #f1f1f1;
# }
# #T_f2f06_row6_col7, #T_f2f06_row7_col6 {
#   background-color: #d85646;
#   color: #f1f1f1;
# }
# #T_f2f06_row6_col8, #T_f2f06_row12_col7 {
#   background-color: #4a63d3;
#   color: #f1f1f1;
# }
# #T_f2f06_row6_col9 {
#   background-color: #ef886b;
#   color: #f1f1f1;
# }
# #T_f2f06_row6_col11, #T_f2f06_row7_col15, #T_f2f06_row10_col17, #T_f2f06_row11_col1, #T_f2f06_row11_col4, #T_f2f06_row11_col18 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_f2f06_row6_col12, #T_f2f06_row12_col1, #T_f2f06_row12_col4, #T_f2f06_row12_col18 {
#   background-color: #6180e9;
#   color: #f1f1f1;
# }
# #T_f2f06_row6_col13 {
#   background-color: #f7ac8e;
#   color: #000000;
# }
# #T_f2f06_row6_col14, #T_f2f06_row7_col1, #T_f2f06_row7_col4, #T_f2f06_row7_col18, #T_f2f06_row8_col13 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_f2f06_row6_col15 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }

# %% [markdown]
# La gama de colores empleados y su interpretación coincide con la del gráfico anterior. Se destaca que contamos con los valores de la matriz de correlaciones. Así se observa que los siguientes pares de variables están altamente correlados:
#
# 1. Latitude - Y
#
# 2. YUTM - Y
#
# 3. Longitude - X
#
# 4. Nsta - Ndef
#
# 5. Smin - ErrTime
#
# 6. Smin - Smaj
#
# En concreto, presentan un coeficiente de correlación superior a 0.8. Por ende, podríamos eliminar una variable por cada par. Se ejecutan los modelos eliminando una u otra variable dentro del par, se eliminan aquellas que dan como resultado un mayor error.
#
# También se elimina la variable XUTM, aunque no muestre correlación con otras variables debido a que presenta la misma información que la longitud.

# %%
df_feat = df_feat.drop(['X','Y', 'Smaj', 'Smin', 'Nsta', 'XUTM','YUTM'],axis=1)
#df_feat = df_feat.drop(['X','Y', 'ErrTime', 'Smaj', 'Nsta', 'XUTM','YUTM'],axis=1)
#df_feat = df_feat.drop(['X','Y', 'Smaj', 'Smin', 'Ndef', 'XUTM','YUTM'],axis=1)
#df_feat = df_feat.drop(['X','Y', 'ErrTime','Smaj', 'Ndef', 'XUTM','YUTM'],axis=1)
df_feat.head()
# Out:
#    ErrTime   RMS  Latitude  Longitude    Az  Depth  ErrDepth  Ndef    Gap  \
# 0     2.18  0.19   28.5661   -17.8807  81.0   21.6      12.7   9.0  189.0
# 1     2.19  0.20   28.5584   -17.8508  67.0   28.2      13.0   8.0  149.0
# 2     2.33  0.16   28.5719   -17.8735  87.0   24.2      14.0   8.0  181.0
# 3     2.44  0.11   28.5656   -17.8802  87.0   24.4      13.7   8.0  189.0
# 4     1.93  0.17   28.5499   -17.8549  90.0   26.3      11.5  10.0  168.0
#
#    mdist  Mdist_  Magnitud
# 0   0.02    0.20       1.6
# 1   0.03    0.13       2.7
# 2   0.01    0.19       1.7
# 3   0.02    0.20       1.7
# 4   0.03    0.20       2.6

# %%
corr_df = df_feat.corr(method='pearson')

print("El DataFrame de correlaciones es:")
print(corr_df, "\n")
# Out:
# El DataFrame de correlaciones es:
#             ErrTime       RMS  Latitude  Longitude        Az     Depth  \
# ErrTime    1.000000 -0.281757 -0.179837  -0.149929 -0.352597  0.580249
# RMS       -0.281757  1.000000 -0.082394   0.161982  0.079522 -0.051372
# Latitude  -0.179837 -0.082394  1.000000   0.145250  0.676339 -0.467162
# Longitude -0.149929  0.161982  0.145250   1.000000  0.134751  0.021400
# Az        -0.352597  0.079522  0.676339   0.134751  1.000000 -0.471126
# Depth      0.580249 -0.051372 -0.467162   0.021400 -0.471126  1.000000
# ErrDepth   0.789362 -0.109115 -0.074598   0.056517 -0.201956  0.502214
# Ndef      -0.511128  0.315976 -0.418152   0.113241 -0.225289  0.066127
# Gap        0.662708 -0.104339  0.005662  -0.149383 -0.214403  0.254239
# mdist      0.071121  0.209374  0.076234   0.397034  0.033810 -0.014195
# Mdist_    -0.279091  0.400242 -0.237587   0.109222 -0.064002  0.117150
# Magnitud  -0.265741  0.256920 -0.590548   0.045353 -0.443147  0.310870
#
#            ErrDepth      Ndef       Gap     mdist    Mdist_  Magnitud
# ErrTime    0.789362 -0.511128  0.662708  0.071121 -0.279091 -0.265741
# RMS       -0.109115  0.315976 -0.104339  0.209374  0.400242  0.256920
# Latitude  -0.074598 -0.418152  0.005662  0.076234 -0.237587 -0.590548
# Longitude  0.056517  0.113241 -0.149383  0.397034  0.109222  0.045353
# Az        -0.201956 -0.225289 -0.214403  0.033810 -0.064002 -0.443147
# Depth      0.502214  0.066127  0.254239 -0.014195  0.117150  0.310870
# ErrDepth   1.000000 -0.426497  0.569138  0.378621 -0.089125 -0.211198
# Ndef      -0.426497  1.000000 -0.502973 -0.059649  0.510230  0.773304
# Gap        0.569138 -0.502973  1.000000  0.262638 -0.182965 -0.361787
# mdist      0.378621 -0.059649  0.262638  1.000000  0.118597 -0.080076
# Mdist_    -0.089125  0.510230 -0.182965  0.118597  1.000000  0.492825
# Magnitud  -0.211198  0.773304 -0.361787 -0.080076  0.492825  1.000000

# %%
R = df_feat.corr()

sns.set(style="white")
mask = np.zeros_like(corr_df, dtype=bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(11, 9))

# Generate a custom diverging colormap
cmap = sns.diverging_palette(200, 10, as_cmap=True)

sns.heatmap(corr_df,mask=mask, cmap=cmap,square = True, linewidths=.5, cbar_kws={"shrink": .5}, ax=ax)
# Out:
# <Axes: >

# %%
corr_df.style.background_gradient(cmap='coolwarm')
# Out:
# <style type="text/css">
# #T_b19f7_row0_col0, #T_b19f7_row1_col1, #T_b19f7_row2_col2, #T_b19f7_row3_col3, #T_b19f7_row4_col4, #T_b19f7_row5_col5, #T_b19f7_row6_col6, #T_b19f7_row7_col7, #T_b19f7_row8_col8, #T_b19f7_row9_col9, #T_b19f7_row10_col10, #T_b19f7_row11_col11 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_b19f7_row0_col1, #T_b19f7_row0_col3, #T_b19f7_row0_col7, #T_b19f7_row0_col10, #T_b19f7_row2_col5, #T_b19f7_row2_col11, #T_b19f7_row4_col5, #T_b19f7_row5_col4, #T_b19f7_row7_col0, #T_b19f7_row7_col6, #T_b19f7_row7_col8, #T_b19f7_row8_col3, #T_b19f7_row11_col2, #T_b19f7_row11_col9 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_b19f7_row0_col2 {
#   background-color: #90b2fe;
#   color: #000000;
# }
# #T_b19f7_row0_col4 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_b19f7_row0_col5, #T_b19f7_row6_col8 {
#   background-color: #f7a889;
#   color: #000000;
# }
# #T_b19f7_row0_col6 {
#   background-color: #e36b54;
#   color: #f1f1f1;
# }
# #T_b19f7_row0_col8, #T_b19f7_row8_col0 {
#   background-color: #f18f71;
#   color: #f1f1f1;
# }
# #T_b19f7_row0_col9, #T_b19f7_row8_col1 {
#   background-color: #6687ed;
#   color: #f1f1f1;
# }
# #T_b19f7_row0_col11 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_b19f7_row1_col0, #T_b19f7_row5_col3, #T_b19f7_row6_col10, #T_b19f7_row11_col6 {
#   background-color: #6a8bef;
#   color: #f1f1f1;
# }
# #T_b19f7_row1_col2, #T_b19f7_row8_col9 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_b19f7_row1_col3 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_b19f7_row1_col4, #T_b19f7_row8_col2 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_b19f7_row1_col5 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_b19f7_row1_col6, #T_b19f7_row2_col0, #T_b19f7_row10_col2 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_b19f7_row1_col7 {
#   background-color: #e9d5cb;
#   color: #000000;
# }
# #T_b19f7_row1_col8 {
#   background-color: #92b4fe;
#   color: #000000;
# }
# #T_b19f7_row1_col9 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_b19f7_row1_col10 {
#   background-color: #e4d9d2;
#   color: #000000;
# }
# #T_b19f7_row1_col11, #T_b19f7_row10_col1, #T_b19f7_row11_col5 {
#   background-color: #e5d8d1;
#   color: #000000;
# }
# #T_b19f7_row2_col1, #T_b19f7_row10_col0 {
#   background-color: #6b8df0;
#   color: #f1f1f1;
# }
# #T_b19f7_row2_col3 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_b19f7_row2_col4 {
#   background-color: #f18d6f;
#   color: #f1f1f1;
# }
# #T_b19f7_row2_col6, #T_b19f7_row4_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_b19f7_row2_col7, #T_b19f7_row5_col9 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_b19f7_row2_col8, #T_b19f7_row3_col6 {
#   background-color: #abc8fd;
#   color: #000000;
# }
# #T_b19f7_row2_col9 {
#   background-color: #688aef;
#   color: #f1f1f1;
# }
# #T_b19f7_row2_col10 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_b19f7_row3_col0, #T_b19f7_row6_col11 {
#   background-color: #89acfd;
#   color: #000000;
# }
# #T_b19f7_row3_col1 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_b19f7_row3_col2 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_b19f7_row3_col4, #T_b19f7_row3_col7 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_b19f7_row3_col5 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# #T_b19f7_row3_col8, #T_b19f7_row10_col6 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_b19f7_row3_col9 {
#   background-color: #cdd9ec;
#   color: #000000;
# }
# #T_b19f7_row3_col10 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_b19f7_row3_col11, #T_b19f7_row10_col5 {
#   background-color: #c0d4f5;
#   color: #000000;
# }
# #T_b19f7_row4_col0, #T_b19f7_row4_col9 {
#   background-color: #5a78e4;
#   color: #f1f1f1;
# }
# #T_b19f7_row4_col1 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_b19f7_row4_col2 {
#   background-color: #ee8669;
#   color: #f1f1f1;
# }
# #T_b19f7_row4_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_b19f7_row4_col7 {
#   background-color: #779af7;
#   color: #f1f1f1;
# }
# #T_b19f7_row4_col8 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_b19f7_row4_col10, #T_b19f7_row11_col3 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_b19f7_row4_col11 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_b19f7_row5_col0 {
#   background-color: #f6a586;
#   color: #000000;
# }
# #T_b19f7_row5_col1, #T_b19f7_row6_col4 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_b19f7_row5_col2, #T_b19f7_row8_col10 {
#   background-color: #516ddb;
#   color: #f1f1f1;
# }
# #T_b19f7_row5_col6 {
#   background-color: #f6bda2;
#   color: #000000;
# }
# #T_b19f7_row5_col7 {
#   background-color: #bad0f8;
#   color: #000000;
# }
# #T_b19f7_row5_col8 {
#   background-color: #dddcdc;
#   color: #000000;
# }
# #T_b19f7_row5_col10, #T_b19f7_row9_col5, #T_b19f7_row9_col10 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_b19f7_row5_col11 {
#   background-color: #edd2c3;
#   color: #000000;
# }
# #T_b19f7_row6_col0 {
#   background-color: #e16751;
#   color: #f1f1f1;
# }
# #T_b19f7_row6_col1 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_b19f7_row6_col2 {
#   background-color: #a7c5fe;
#   color: #000000;
# }
# #T_b19f7_row6_col3 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_b19f7_row6_col5 {
#   background-color: #f7b99e;
#   color: #000000;
# }
# #T_b19f7_row6_col7 {
#   background-color: #4b64d5;
#   color: #f1f1f1;
# }
# #T_b19f7_row6_col9 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_b19f7_row7_col1 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_b19f7_row7_col2 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_b19f7_row7_col3 {
#   background-color: #85a8fc;
#   color: #f1f1f1;
# }
# #T_b19f7_row7_col4 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_b19f7_row7_col5 {
#   background-color: #b5cdfa;
#   color: #000000;
# }
# #T_b19f7_row7_col9, #T_b19f7_row11_col4 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_b19f7_row7_col10 {
#   background-color: #f3c7b1;
#   color: #000000;
# }
# #T_b19f7_row7_col11 {
#   background-color: #e26952;
#   color: #f1f1f1;
# }
# #T_b19f7_row8_col4 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_b19f7_row8_col5 {
#   background-color: #dbdcde;
#   color: #000000;
# }
# #T_b19f7_row8_col6 {
#   background-color: #f7ad90;
#   color: #000000;
# }
# #T_b19f7_row8_col7 {
#   background-color: #3c4ec2;
#   color: #f1f1f1;
# }
# #T_b19f7_row8_col11 {
#   background-color: #6788ee;
#   color: #f1f1f1;
# }
# #T_b19f7_row9_col0, #T_b19f7_row9_col1 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_b19f7_row9_col2, #T_b19f7_row11_col1 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_b19f7_row9_col3 {
#   background-color: #d6dce4;
#   color: #000000;
# }
# #T_b19f7_row9_col4 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_b19f7_row9_col6 {
#   background-color: #ecd3c5;
#   color: #000000;
# }
# #T_b19f7_row9_col7 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_b19f7_row9_col8 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_b19f7_row9_col11 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_b19f7_row10_col3 {
#   background-color: #84a7fc;
#   color: #f1f1f1;
# }
# #T_b19f7_row10_col4 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_b19f7_row10_col7 {
#   background-color: #f7b497;
#   color: #000000;
# }
# #T_b19f7_row10_col8 {
#   background-color: #80a3fa;
#   color: #f1f1f1;
# }
# #T_b19f7_row10_col9 {
#   background-color: #7699f6;
#   color: #f1f1f1;
# }
# #T_b19f7_row10_col11 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_b19f7_row11_col0 {
#   background-color: #6e90f2;
#   color: #f1f1f1;
# }
# #T_b19f7_row11_col7 {
#   background-color: #e36c55;
#   color: #f1f1f1;
# }
# #T_b19f7_row11_col8 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_b19f7_row11_col10 {
#   background-color: #f2cab5;
#   color: #000000;
# }
# </style>
# <table id="T_b19f7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b19f7_level0_col0" class="col_heading level0 col0" >ErrTime</th>
#       <th id="T_b19f7_level0_col1" class="col_heading level0 col1" >RMS</th>
#       <th id="T_b19f7_level0_col2" class="col_heading level0 col2" >Latitude</th>
#       <th id="T_b19f7_level0_col3" class="col_heading level0 col3" >Longitude</th>
#       <th id="T_b19f7_level0_col4" class="col_heading level0 col

# %% [markdown]
# Los modelos tradicionales como la Regresión Lineal o incluso redes neuronales recurrentes como LSTM no pueden interpretar automáticamente Latitud y Longitud como información espacial.
#
# Si la mayoría de los sismos en el dataset ocurren en una zona específica, la regresión lineal podría aprender que la magnitud está relacionada con la ubicación, cuando en realidad es una coincidencia. Esto reduce la capacidad de generalización del modelo.
#
# Se podría considerar convertir las variables de posición del sismo en una distancia a un punto relevante como el epicentro de la erupción o a una falla activa. Sin embargo, esto no es aplicacle a este caso.
#
# Por esto, se eliminan también las variables 'Latitude' y 'Longitude'.

# %%
df_feat = df_feat.drop(['Longitude','Latitude'],axis=1)
df_feat.head()
# Out:
#    ErrTime   RMS    Az  Depth  ErrDepth  Ndef    Gap  mdist  Mdist_  Magnitud
# 0     2.18  0.19  81.0   21.6      12.7   9.0  189.0   0.02    0.20       1.6
# 1     2.19  0.20  67.0   28.2      13.0   8.0  149.0   0.03    0.13       2.7
# 2     2.33  0.16  87.0   24.2      14.0   8.0  181.0   0.01    0.19       1.7
# 3     2.44  0.11  87.0   24.4      13.7   8.0  189.0   0.02    0.20       1.7
# 4     1.93  0.17  90.0   26.3      11.5  10.0  168.0   0.03    0.20       2.6
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['ErrTime'].plot(kind='hist', bins=20, title='ErrTime')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['RMS'].plot(kind='hist', bins=20, title='RMS')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['Az'].plot(kind='hist', bins=20, title='Az')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['Depth'].plot(kind='hist', bins=20, title='Depth')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='ErrTime', y='RMS', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_5.plot(kind='scatter', x='RMS', y='Az', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6.plot(kind='scatter', x='Az', y='Depth', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_7.plot(kind='scatter', x='Depth', y='ErrDepth', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['ErrTime']
#   ys = series['RMS']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_8.sort_values('ErrTime', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('ErrTime')
# _ = plt.ylabel('RMS')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['ErrTime']
#   ys = series['Az']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_9.sort_values('ErrTime', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('ErrTime')
# _ = plt.ylabel('Az')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['ErrTime']
#   ys = series['Depth']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_10.sort_values('ErrTime', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('ErrTime')
# _ = plt.ylabel('Depth')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['ErrTime']
#   ys = series['ErrDepth']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = _df_11.sort_values('ErrTime', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('ErrTime')
# _ = plt.ylabel('ErrDepth')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_12['ErrTime'].plot(kind='line', figsize=(8, 4), title='ErrTime')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_13['RMS'].plot(kind='line', figsize=(8, 4), title='RMS')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_14['Az'].plot(kind='line', figsize=(8, 4), title='Az')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_15['Depth'].plot(kind='line', figsize=(8, 4), title='Depth')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# prompt: curvas distribución de todas las variables y que se vean todas en chiquitito

import matplotlib.pyplot as plt

# Assuming 'df_feat' is your DataFrame with the numerical features
for column in df_feat.columns:
  plt.figure(figsize=(4, 3))  # Adjust size as needed
  plt.hist(df_feat[column], bins=20)  # You can adjust the number of bins
  plt.title(f'Distribution of {column}')
  plt.xlabel(column)
  plt.ylabel('Frequency')
  plt.tight_layout()  # Prevents overlapping labels
  plt.show()

# %%
#Guardar DataFrame en CSV
df_feat.to_csv('Datos_resultantes0.8.csv', index=False)

# %%
# Definir proporción de división (70% entrenamiento, 30% prueba)
train_size = int(0.7 * len(df_feat))

# Dividir datos sin aleatorizar
train = df_feat.iloc[:train_size]  # Primer 70% para entrenamiento
test = df_feat.iloc[train_size:]   # Último 30% para prueba

# Verificar tamaños
print(f"Tamaño del conjunto de entrenamiento: {train.shape}")
print(f"Tamaño del conjunto de prueba: {test.shape}")
# Out:
# Tamaño del conjunto de entrenamiento: (10893, 10)
# Tamaño del conjunto de prueba: (4669, 10)

# %% [markdown]
# #Optimización de hiperparámetros

# %% [markdown]
# #1. Parametrización
#
# Todo modelos de aprendizaje automático necesitan de cierta parametrización con el fin de que su comportamiento se ajuste mejor a cada problema concreto.
# Según la naturaleza del modelo este puede tener muchos parámetros y encontrar la mejor combinación de los mismos puede ser tratado como un problema de búsqueda/optimización.
#
# Este problema es denominado habitualmente **optimización de hiperparámetros**, donde los parámetros del algoritmo se denominan hiperparámetros, mientras que los coeficientes encontrados por el propio algoritmo de aprendizaje se denominan *parámetros*.
#
# El planteamiento será del de buscar aquella parametrización que ofrezca los resultados de mayor calidad (con respecto a las métricas establecidas) y de mayor robustez.
#
# Scikit-learn proporciona diferentes herramientas para que la optimización de estos hiperparámetros pueda ser lo más sencilla posible. En concreto ofrece dos alternativas, la *búsqueda en cuadrícula* (**grid search**) y la *búsqueda aleatoria* (**RandomSearch**)

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import randint as sp_randint

from sklearn.ensemble import RandomForestRegressor


from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# Para utilizar estas herramientas de búsqueda, primero necesitamos crear el conjunto de parámetros a muestrear durante el proceso de optimización.

# %% [markdown]
# Y crear (construir) el elemento que va a ser nuestro regresor

# %%
regressor = RandomForestRegressor()
regressor
# Out:
# RandomForestRegressor()

# %% [markdown]
# ## GridSearch
#
# La búsqueda en cuadrícula es un enfoque de ajuste de parámetros que permite construir y evaluar metódicamente un modelo para cada combinación de parámetros de algoritmo especificados en una cuadrícula.

# %%
def report(results, n_top=3): # Función para mostrar resultados
    for i in range(1, n_top + 1):
        candidates = np.flatnonzero(results['rank_test_score'] == i)
        for candidate in candidates:
            print("Model with rank: {0}".format(i))
            print("Mean validation score: {0:.3f} (std: {1:.3f})".format(
                  results['mean_test_score'][candidate],
                  results['std_test_score'][candidate]))
            print("Parameters: {0}".format(results['params'][candidate]))
            print("")

# %%
param_dist = {"n_estimators": [32, 64, 128], # Number of trees in random forest
              "max_features": ['auto', 'sqrt'], # Number of features to consider at every split
              "max_depth": [8,4, 2], # Maximum number of levels in tree
              "min_samples_split": [2, 4, 6], #  Minimum number of samples required to split a node
              "min_samples_leaf": [8, 12, 16], # Minimum number of samples required at each leaf node
              "bootstrap": [True, False] # Method of selecting samples for training each tree
            }

# %%
grid_regres = GridSearchCV(estimator = regressor, param_grid= param_dist, cv=5)

# Fit the random search model
grid_regres.fit(X = train.drop(['Magnitud'], axis=1), y = train['Magnitud'])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 810 fits failed out of a total of 1620.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 810 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'log2', 'sqrt'} or None. Got 'auto' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [            nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan  4.85437740e-02
#   5.89460518e-02  9.04090627e-02  5.24883543e-02  4.61019330e-02
#   8.28133760e-02  1.36603522e-01  7.48894490e-02  7.19647671e-02
#   5.32015339e-02 -5.55318260e-03  4.07012810e-02  3.53995107e-02
#   5.58560654e-02  3.04854519e-02  3.23876059e-02 -7.71410147e-03
#   7.16819299e-02 -4.38270236e-03  1.33056791e-02 -1.18543453e-03
#  -4.47883709e-02 -1.98223671e-02 -4.02159299e-04 -4.47092026e-03
#  -4.20375711e-02 -1.59191895e-02             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan -3.61780269e-01 -3.60621114e-01 -3.63861579e-01
#  -4.08006209e-01 -3.73727983e-01 -3.66128680e-01 -3.84582710e-01
#  -3.40041413e-01 -3.66612787e-01 -2.89294309e-01 -3.62992629e-01
#  -3.87711876e-01 -4.03712148e-01 -3.42123450e-01 -3.63790003e-01
#  -3.39433977e-01 -3.86670241e-01 -3.85879957e-01 -4.34274360e-01
#  -3.88447660e-01 -3.94280645e-01 -4.51770577e-01 -3.54268686e-01
#  -3.69694315e-01 -3.48480652e-01 -4.11052891e-01 -4.11923866e-01
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan -1.16494474e+00
#  -1.22935122e+00 -1.15714076e+00 -1.34032000e+00 -1.18280362e+00
#  -1.21654422e+00 -1.22425928e+00 -1.11478127e+00 -1.15914650e+00
#  -1.34768137e+00 -1.17383384e+00 -1.20665261e+00 -1.29218528e+00
#  -1.27321183e+00 -1.21966480e+00 -1.19424452e+00 -1.27591359e+00
#  -1.22719007e+00 -1.16461967e+00 -1.22218831e+00 -1.19087356e+00
#  -1.29217012e+00 -1.12200836e+00 -1.18096604e+00 -1.20605194e+00
#  -1.33048716e+00 -1.17620582e+00             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan  9.51124470e-02  1.32797441e-01  1.07921019e-01
#   1.30287181e-01  1.52946057e-01  1.30777252e-01  1.13834226e-01
#   1.37202156e-01  1.03029917e-01  5.94566534e-02  1.07456631e-01
#   6.91066667e-02  7.94512419e-02  8.53449733e-02  8.84743186e-02
#   6.21488862e-02  1.21009913e-01  8.28744780e-02  5.89311130e-02
#   4.11570430e-02  6.35469920e-02  4.87732354e-02  7.87612825e-02
#   7.21604928e-02  7.49701415e-02  4.92535765e-02  8.83579477e-02
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan -4.13336476e-01
#  -4.19005166e-01 -3.66736483e-01 -2.88772273e-01 -3.23396660e-01
#  -3.62044210e-01 -3.76183476e-01 -3.34555489e-01 -3.45385824e-01
#  -4.00315834e-01 -3.87155732e-01 -3.85044947e-01 -3.93881203e-01
#  -4.11762557e-01 -3.46985686e-01 -3.79825232e-01 -4.00411560e-01
#  -3.27503300e-01 -3.31272530e-01 -4.06395758e-01 -3.81718687e-01
#  -3.96148269e-01 -3.78366145e-01 -3.89166657e-01 -4.06827493e-01
#  -3.16052027e-01 -3.44870331e-01             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan             nan             nan             nan
#              nan -1.32251875e+00 -1.19654023e+00 -1.25993993e+00
#  -1.22959185e+00 -1.26768145e+00 -1.24471668e+00 -1.20328294e+00
#  -1.28092803e+00 -1.20475827e+00 -1.24551531e+00 -1.34010709e+00
#  -1.29913147e+00 -1.40673628e+00 -1.28756409e+00 -1.19463884e+00
#  -1.24784333e+00 -1.27824095e+00 -1.13933085e+00 -1.23016260e+00
#  -1.35645789e+00 -1.25433898e+00 -1.25937393e+00 -1.27299887e+00
#  -1.14306441e+00 -1.38523562e+00 -1.31186271e+00 -1.22525381e+00]
#   warnings.warn(
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'bootstrap': [True, False], 'max_depth': [8, 4, 2],
#                          'max_features': ['auto', 'sqrt'],
#                          'min_samples_leaf': [8, 12, 16],
#                          'min_samples_split': [2, 4, 6],
#                          'n_estimators': [32, 64, 128]})

# %%
report(grid_regres.cv_results_, n_top = 10)
# Out:
# Model with rank: 1
# Mean validation score: 0.153 (std: 1.063)
# Parameters: {'bootstrap': False, 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 4, 'n_estimators': 64}
#
# Model with rank: 2
# Mean validation score: 0.137 (std: 1.074)
# Parameters: {'bootstrap': False, 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 6, 'n_estimators': 64}
#
# Model with rank: 3
# Mean validation score: 0.137 (std: 1.103)
# Parameters: {'bootstrap': True, 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 6, 'n_estimators': 32}
#
# Model with rank: 4
# Mean validation score: 0.133 (std: 1.093)
# Parameters: {'bootstrap': False, 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 64}
#
# Model with rank: 5
# Mean validation score: 0.131 (std: 1.079)
# Parameters: {'bootstrap': False, 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 4, 'n_estimators': 128}
#
# Model with rank: 6
# Mean validation score: 0.130 (std: 1.077)
# Parameters: {'bootstrap': False, 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 4, 'n_estimators': 32}
#
# Model with rank: 7
# Mean validation score: 0.121 (std: 1.097)
# Parameters: {'bootstrap': False, 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 12, 'min_samples_split': 6, 'n_estimators': 64}
#
# Model with rank: 8
# Mean validation score: 0.114 (std: 1.076)
# Parameters: {'bootstrap': False, 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 6, 'n_estimators': 32}
#
# Model with rank: 9
# Mean validation score: 0.108 (std: 1.124)
# Parameters: {'bootstrap': False, 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 8, 'min_samples_split': 2, 'n_estimators': 128}
#
# Model with rank: 10
# Mean validation score: 0.107 (std: 1.123)
# Parameters: {'bootstrap': False, 'max_depth': 8, 'max_features': 'sqrt', 'min_samples_leaf': 12, 'min_samples_split': 2, 'n_estimators': 64}

# %%
grid_regres.best_estimator_
# Out:
# RandomForestRegressor(bootstrap=False, max_depth=8, max_features='sqrt',
#                       min_samples_leaf=8, min_samples_split=4, n_estimators=64)

# %%
# choose the best
best_grid = grid_regres.best_estimator_

# fit and predict
best_grid.fit( X = train.drop(['Magnitud'], axis=1), y = train['Magnitud'])
y_pred = best_grid.predict(X = test.drop(['Magnitud'], axis = 1))

# EVALUATE
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(test['Magnitud'], y_pred)
print ('MAE', mae)

# EVALUATE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(test['Magnitud'], y_pred)
print ('MSE', mse)


# EVALUATE
import math
rmse = math.sqrt(mse)
print ('RMSE', rmse)
# Out:
# MAE 0.3194309689854878
# MSE 0.19663313233729407
# RMSE 0.4434333459915865

# %%
from sklearn.metrics import mean_absolute_error


# x axis for plotting
import numpy as np
xx = np.stack([i for i in range(test['Magnitud'].shape[0])])
plt.plot(xx, test['Magnitud'], c='r', label='data')
plt.plot(xx, y_pred, c='g', label='prediction')
plt.axis('tight')
plt.legend()
plt.title("RandomForests GridSearchCV (MAE = %6.2f')" % ( mae))

plt.show()

# %%
print(train.values)
# Out:
# [[2.18e+00 1.90e-01 8.10e+01 ... 2.00e-02 2.00e-01 1.60e+00]
#  [2.19e+00 2.00e-01 6.70e+01 ... 3.00e-02 1.30e-01 2.70e+00]
#  [2.33e+00 1.60e-01 8.70e+01 ... 1.00e-02 1.90e-01 1.70e+00]
#  ...
#  [4.90e-01 3.60e-01 7.50e+01 ... 4.00e-02 2.30e-01 2.40e+00]
#  [1.09e+00 2.20e-01 9.10e+01 ... 3.00e-02 2.60e-01 2.70e+00]
#  [1.33e+00 1.40e-01 1.00e+02 ... 3.00e-02 2.50e-01 3.00e+00]]

# %%
# FEATURE RELEVANCIES
print ('Feature Relevancies')
pd.DataFrame({'Attributes': ('ErrTime','RMS','Az', 'Depth', 'ErrDepth','Ndef','Gap','mdist','Mdist_'),
              'Decision Tree': best_grid.feature_importances_})
# Out:
# Feature Relevancies
#   Attributes  Decision Tree
# 0    ErrTime       0.077963
# 1        RMS       0.013951
# 2         Az       0.130688
# 3      Depth       0.108465
# 4   ErrDepth       0.035367
# 5       Ndef       0.354665
# 6        Gap       0.053771
# 7      mdist       0.003899
# 8     Mdist_       0.221231

# %% [markdown]
# ## RandomizedSearch
#
# Para utilizar RandomizedSearchCV, primero necesitamos crear el conjunto de parámetros a muestrear durante el proceso de optimización.

# %%
param_dist = {"n_estimators": [4, 8, 16, 32, 64, 128], # Number of trees in random forest
              "max_features": ['auto', 'sqrt'], # Number of features to consider at every split
              "max_depth": [16, 12,8,4, 2,None], # Maximum number of levels in tree
              "min_samples_split": sp_randint(2, 50), #  Minimum number of samples required to split a node
              "min_samples_leaf": sp_randint(1, 50), # Minimum number of samples required at each leaf node
              "bootstrap": [True, False], # Method of selecting samples for training each tree
              "criterion": ["mse", "absolute_error"]}

# %% [markdown]
# n cada iteración, el algoritmo elegirá una combinación diferente de las características. Si se probaran de forma exhaustiva todas las características el problema se volvería muy costoso computacionalmente. Al menos al utilizar búsqueda aleatoria se seleccionará al azar una muestra de las mismas para buscar en un reducido pero significativo rango de valores.
#
#
# Los argumentos más importantes en RandomizedSearchCV son *n_iter*, que controla el número de combinaciones diferentes a probar, y *cv*, que es el número de *cruces* a usar para la validación cruzada. Más iteraciones cubrirán un espacio de búsqueda más amplio y más *cruces* de cv reducen las posibilidades de sobreaprendizaje, pero al aumentar cada una de ellas se incrementará el tiempo de ejecución.
#
# Vamos a ejecutarla utilizando la validación cruzada (5-fold) y posteriormente busca entre 100 combinaciones diferentes de entre las especificadas

# %%
rnd_regres = RandomizedSearchCV(estimator = regressor, param_distributions = param_dist,
                               n_iter = 100, cv = 5, random_state=0, n_jobs = -1)

# Fit the random search model
rnd_regres.fit(X = train.drop(['Magnitud'], axis=1),
                           y = train['Magnitud'])
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py:528: FitFailedWarning:
# 355 fits failed out of a total of 500.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 135 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'max_features' parameter of RandomForestRegressor must be an int in the range [1, inf), a float in the range (0.0, 1.0], a str among {'sqrt', 'log2'} or None. Got 'auto' instead.
#
# --------------------------------------------------------------------------------
# 220 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_validation.py", line 866, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 1382, in wrapper
#     estimator._validate_params()
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/base.py", line 436, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.11/dist-packages/sklearn/utils/_param_validation.py", line 98, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'criterion' parameter of RandomForestRegressor must be a str among {'absolute_error', 'squared_error', 'poisson', 'friedman_mse'}. Got 'mse' instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.11/dist-packages/sklearn/model_selection/_search.py:1108: UserWarning: One or more of the test scores are non-finite: [        nan         nan         nan  0.12934316         nan -0.21015504
#   0.112219           nan         nan -1.62802308 -0.0645476          nan
#          nan -1.25184282         nan  0.14017502         nan         nan
#   0.22704749         nan         nan         nan         nan         nan
#          nan         nan         nan -0.12649807         nan         nan
#          nan         nan         nan         nan         nan         nan
#          nan -0.56085816 -0.44003948         nan -0.14960138         nan
#          nan         nan -0.3555169  -1.37429343         nan         nan
#          nan -0.54432515         nan         nan         nan         nan
#          nan         nan         nan         nan         nan -0.52943437
#          nan -0.21905646         nan  0.08918989         nan         nan
#          nan -0.03363783 -0.07010857 -0.07542088         nan         nan
#          nan -0.39996231         nan         nan         nan         nan
#  -0.4352144          nan -1.48238928         nan         nan         nan
#          nan -0.08674533  0.22250882 -1.34163671         nan         nan
#          nan  0.02099552         nan         nan         nan         nan
#          nan -0.14495887         nan         nan]
#   warnings.warn(
# RandomizedSearchCV(cv=5, estimator=RandomForestRegressor(), n_iter=100,
#                    n_jobs=-1,
#                    param_distributions={'bootstrap': [True, False],
#                                         'criterion': ['mse', 'absolute_error'],
#                                         'max_depth': [16, 12, 8, 4, 2, None],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x78617d8ff250>,
#                                         'min_samples_split': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x78617da0a150>,
#                                         'n_estimators': [4, 8, 16, 32, 64,
#                                                          128]},
#                    random_state=0)

# %%
report(rnd_regres.cv_results_, n_top = 5)
# Out:
# Model with rank: 1
# Mean validation score: 0.227 (std: 1.115)
# Parameters: {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 12, 'max_features': 'sqrt', 'min_samples_leaf': 1, 'min_samples_split': 12, 'n_estimators': 16}
#
# Model with rank: 2
# Mean validation score: 0.223 (std: 1.154)
# Parameters: {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 12, 'max_features': 'sqrt', 'min_samples_leaf': 3, 'min_samples_split': 22, 'n_estimators': 128}
#
# Model with rank: 3
# Mean validation score: 0.140 (std: 1.321)
# Parameters: {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 16, 'max_features': 'sqrt', 'min_samples_leaf': 6, 'min_samples_split': 43, 'n_estimators': 32}
#
# Model with rank: 4
# Mean validation score: 0.129 (std: 1.341)
# Parameters: {'bootstrap': False, 'criterion': 'absolute_error', 'max_depth': 12, 'max_features': 'sqrt', 'min_samples_leaf': 9, 'min_samples_split': 11, 'n_estimators': 64}
#
# Model with rank: 5
# Mean validation score: 0.112 (std: 1.334)
# Parameters: {'bootstrap': True, 'criterion': 'absolute_error', 'max_depth': 16, 'max_features': 'sqrt', 'min_samples_leaf': 10, 'min_samples_split': 34, 'n_estimators': 16}

# %%
rnd_regres.best_params_
# Out:
# {'bootstrap': False,
#  'criterion': 'absolute_error',
#  'max_depth': 12,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 12,
#  'n_estimators': 16}

# %% [markdown]
# Una vez que hemos identificado la mejor parametrización vamos a pasar a hacer una ejecución del modelo y vamos graficar sus resultados.
#
# Recordamos que al final del paso 1 hemos dividido en entrenamiento/tuneado y test

# %% [markdown]
# Posteriormente, vamos a ejecutar el modelo con la mejor parametrización que hayamos obtenido anteriormente

# %%
# choose the best

best_random = rnd_regres.best_estimator_
# fit and predict
best_random.fit( X = train.drop(['Magnitud'], axis=1), y = train['Magnitud'])
y_pred = best_random.predict(X = test.drop(['Magnitud'], axis = 1))

# EVALUATE
from sklearn.metrics import mean_absolute_error
mae = mean_absolute_error(test['Magnitud'], y_pred)
print ('MAE', mae)

# EVALUATE
from sklearn.metrics import mean_squared_error
mse = mean_squared_error(test['Magnitud'], y_pred)
print ('MSE', mse)


# EVALUATE
import math
rmse = math.sqrt(mse)
print ('RMSE', rmse)
# Out:
# MAE 0.310443885200257
# MSE 0.18456060334787966
# RMSE 0.4296051714631467

# %% [markdown]
# Por último probamos visualizamos como ha quedado nuestra predicción con la realidad.

# %%
from sklearn.metrics import mean_absolute_error


# x axis for plotting
import numpy as np
xx = np.stack([i for i in range(test['Magnitud'].shape[0])])
plt.plot(xx, test['Magnitud'], c='r', label='data')
plt.plot(xx, y_pred, c='g', label='prediction')
plt.axis('tight')
plt.legend()
plt.title("RandomForests RandomSearchCV (MAE = %6.2f')" % ( mae))

plt.show()

# %%
# FEATURE RELEVANCIES
print ('Feature Relevancies')
pd.DataFrame({'Attributes': ('ErrTime','RMS','Az', 'Depth', 'ErrDepth','Ndef','Gap','mdist','Mdist_') ,
              'Random Forests': best_random.feature_importances_})
# Out:
# Feature Relevancies
#   Attributes  Random Forests
# 0    ErrTime        0.111669
# 1        RMS        0.032508
# 2         Az        0.205343
# 3      Depth        0.123854
# 4   ErrDepth        0.049681
# 5       Ndef        0.273884
# 6        Gap        0.050133
# 7      mdist        0.013152
# 8     Mdist_        0.139778
